# %%
import pandas as pd

dfi1 = pd.read_excel('SINAPI_Preco_Ref_Insumos_DF_102020_Desonerado.XLS')

# %%
dfi1.columns=dfi1.loc[5]
dfi2=dfi1.loc[6:]
dfi2
# Out:
# 5                    CODIGO    \
# 6                       13003
# 7                       41758
# 8                        1363
# 9                        1344
# 10                       1342
# ...                       ...
# 5283                    41096
# 5284                    41776
# 5285                    11157
# 5286                      NaN
# 5287  TOTAL DE INSUMOS : 5280
#
# 5                                   DESCRICAO DO INSUMO UNIDADE  \
# 6           !EM PROCESSO DE DESATIVACAO! AGUA SANITARIA  L
# 7     !EM PROCESSO DE DESATIVACAO! CADEADO EM ACO IN...  UN
# 8     !EM PROCESSO DE DESATIVACAO! CHAPA DE MADEIRA ...  M2
# 9     !EM PROCESSO DE DESATIVACAO! CHAPA DE MADEIRA ...  UN
# 10    !EM PROCESSO DE DESATIVACAO! CHAPA DE MADEIRA ...  UN
# ...                                                 ...     ...
# 5283                          VIGIA DIURNO (MENSALISTA)  MES
# 5284  VIGIA NOTURNO, HORA EFETIVAMENTE TRABALHADA DE...  H
# ...

# %%
dfi2['  PRECO MEDIANO R$'] = dfi2['  PRECO MEDIANO R$'].apply(lambda x: str(x).replace(".",""))
dfi2['  PRECO MEDIANO R$'] = dfi2['  PRECO MEDIANO R$'].apply(lambda x: str(x).replace(",","."))
dfi2['  PRECO MEDIANO R$'] = dfi2['  PRECO MEDIANO R$'].astype('float64')
# Out:
# <ipython-input-3-e532665f8177>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfi2['  PRECO MEDIANO R$'] = dfi2['  PRECO MEDIANO R$'].apply(lambda x: str(x).replace(".",""))
# <ipython-input-3-e532665f8177>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfi2['  PRECO MEDIANO R$'] = dfi2['  PRECO MEDIANO R$'].apply(lambda x: str(x).replace(",","."))
# <ipython-input-3-e532665f8177>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# ...

# %%
dfi2
# Out:
# 5                    CODIGO    \
# 6                       13003
# 7                       41758
# 8                        1363
# 9                        1344
# 10                       1342
# ...                       ...
# 5283                    41096
# 5284                    41776
# 5285                    11157
# 5286                      NaN
# 5287  TOTAL DE INSUMOS : 5280
#
# 5                                   DESCRICAO DO INSUMO UNIDADE  \
# 6           !EM PROCESSO DE DESATIVACAO! AGUA SANITARIA  L
# 7     !EM PROCESSO DE DESATIVACAO! CADEADO EM ACO IN...  UN
# 8     !EM PROCESSO DE DESATIVACAO! CHAPA DE MADEIRA ...  M2
# 9     !EM PROCESSO DE DESATIVACAO! CHAPA DE MADEIRA ...  UN
# 10    !EM PROCESSO DE DESATIVACAO! CHAPA DE MADEIRA ...  UN
# ...                                                 ...     ...
# 5283                          VIGIA DIURNO (MENSALISTA)  MES
# 5284  VIGIA NOTURNO, HORA EFETIVAMENTE TRABALHADA DE...  H
# ...

# %%
import random

QTD=[random.randint(0, 10) for item in range(len(dfi2))]

dfi2['QTD'] = QTD 
 
display(dfi2)
# Out:
# <ipython-input-5-3b75154fce2a>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfi2['QTD'] = QTD
# 5                    CODIGO    \
# 6                       13003
# 7                       41758
# 8                        1363
# 9                        1344
# 10                       1342
# ...                       ...
# 5283                    41096
# 5284                    41776
# 5285                    11157
# 5286                      NaN
# 5287  TOTAL DE INSUMOS : 5280
#
# 5                                   DESCRICAO DO INSUMO UNIDADE  \
# 6           !EM PROCESSO DE DESATIVACAO! AGUA SANITARIA  L
# 7     !EM PROCESSO DE DESATIVACAO! CADEADO EM ACO IN...  UN
# 8     !EM PROCESSO DE DESATIVACAO! CHAPA DE MADEIRA ...  M2
# ...
